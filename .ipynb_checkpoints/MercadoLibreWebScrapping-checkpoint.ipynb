# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
import time
import re

# %%
# Get data from website
url = "https://listado.mercadolibre.com.mx/deportes-fitness/tenis-paddle-squash/equipamiento/bandas-cabeza/nuevo/bandas-deportivas-para-cabello"

# %%
page_number = 1
products = []

while True:
    # SIMULA LA NAVEGACIÓN
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/89.0.4389.82 Safari/537.36'
    }
    
    # Agrega el número de página a la URL
    response = requests.get(f'{url}_Desde_{(page_number - 1) * 10}_NoIndex_True', headers=headers)
    # response = requests.get(f'{url}_Desde_100_NoIndex_True', headers=headers)
    
    if response.status_code != 200:
        print('Error', page_number)
        break
    
    html = BeautifulSoup(response.text, 'html.parser')

    allData = html.find_all('div', class_="poly-card__content")
    
    if not allData:
        print(f"Total {page_number}")
        break
    
    for data in allData:
        
        description = data.find('h2', class_="poly-box poly-component__title").text
        s = data.find('s', class_="andes-money-amount andes-money-amount--previous andes-money-amount--cents-dot")
        div = data.find('div', class_ = "poly-price__current")
        discountPrice = div.find('span', class_ = "andes-money-amount andes-money-amount--cents-superscript").text.replace("$","").replace(",",".")
        normalPrice = s.text.replace("$","").replace(",",".") if s else None
        a = data.find('a')
        link = a['href'] if a else None
        
        products.append({ "Description" : description ,
                          "Normal Price" :  normalPrice if normalPrice else discountPrice,
                          "Discount Price" : discountPrice if normalPrice is not None else normalPrice,
                          "URL" : a['href'] if a else None
                        })
    page_number += 1
    time.sleep(2)
        
        
#print(products)        
df = pd.DataFrame(products)
# df.to_csv('products.csv')
# Out:
# Total 2

# %%
df.size
# Out:
# 200

# %%
1969-1921
# Out:
# 48

# %%
df = df.sort_values("Discount Price")
df.to_csv('products.csv')
# Obtener toda la fila correspondiente al valor mínimo

# %% [markdown]
# ## FARMACIAS GUADALAJARA

# %%
# from requests_html import HTMLSession

page = 0
URL = f"https://www.farmaciasguadalajara.com/SearchDisplay?categoryId=&storeId=10151&searchType=1001&catalogId=10052&langId=-24&sType=SimpleSearch&resultCatEntryType=2&showResultsPage=true&searchSource=Q&pageView=&beginIndex={page}&pageSize=50&searchTerm=condones"
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/89.0.4389.82 Safari/537.36'
}

# response = requests.get(f'{URL}', headers=headers)
# html = BeautifulSoup(response.text, 'html.parser')
# totalDiv = html.find('div', class_="widget_title_container_position")
# total = totalDiv.find(string= re.compile(r'coincidencias'))
# total = total.split(" ")[0]
# # print(URL)
# URL1 = URL.replace("pageSize=1", f"pageSize={total}")
# print(total)
URL
# session = HTMLSession()
# Out:
# 'https://www.farmaciasguadalajara.com/SearchDisplay?categoryId=&storeId=10151&searchType=1001&catalogId=10052&langId=-24&sType=SimpleSearch&resultCatEntryType=2&showResultsPage=true&searchSource=Q&pageView=&beginIndex=0&pageSize=50&searchTerm=condones'

# %%
products = []
total = 1

end = 52;


# while page<end:
    
URL = "https://www.farmaciasguadalajara.com/SearchDisplay?categoryId=&storeId=10151&searchType=1001&catalogId=10052&langId=-24&sType=SimpleSearch&resultCatEntryType=2&showResultsPage=true&searchSource=Q&pageView=&beginIndex=0&pageSize=53&searchTerm=condones"

response = requests.get(f'{URL}', headers=headers)

if response.status_code != 200:
    print('Error', response.error)

else:

    html = BeautifulSoup(response.text, 'html.parser')
    items = html.find_all('div', class_="product_info")

    
    for item in items:
    
        description = item.find('div', class_="product_name").text.replace("\n","").replace("\t","")
        link = item.find('a')['href']
        oldPrice = item.find('span', class_="old_price").text.replace("\n","").replace("\t","").replace("$","") if item.find('span', class_="old_price") else None
        currentPrice = item.find('span', class_="price").text.replace("\n","").replace("\t","").replace("$","") if item.find('span', class_="price") else None
        
        products.append({
                        "Description" : description,
                        "Old Price" : float(oldPrice) if oldPrice else None,
                        "Current Price" : float(currentPrice) if currentPrice else None,
                        "Link" : link
                        })
page += 50
print(len(products))
    
df = pd.DataFrame(products)
# df = df.sort_values("Current Price", ascending=True)
len(df)# df.to_csv('products.csv')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 11
#       7 # while page<end:
#       9 URL = "https://www.farmaciasguadalajara.com/SearchDisplay?categoryId=&storeId=10151&searchType=1001&catalogId=10052&langId=-24&sType=SimpleSearch&resultCatEntryType=2&showResultsPage=true&searchSource=Q&pageView=&beginIndex=0&pageSize=53&searchTerm=condones"
# ---> 11 response = requests.get(f'{URL}', headers=headers)
#      13 if response.status_code != 200:
#      14     print('Error', response.error)
#
# File /opt/conda/lib/python3.11/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File /opt/conda/lib/python3.11/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File /opt/conda/lib/python3.11/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File /opt/conda/lib/python3.11/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File /opt/conda/lib/python3.11/site-packages/requests/adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File /opt/conda/lib/python3.11/site-packages/urllib3/connectionpool.py:791, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     788 response_conn = conn if not release_conn else None
#     790 # Make the request on the HTTPConnection object
# --> 791 response = self._make_request(
#     792     conn,
#     793     method,
#     794     url,
#     795     timeout=timeout_obj,
#     796     body=body,
#     797     headers=headers,
#     798     chunked=chunked,
#     799     retries=retries,
#     800     response_conn=response_conn,
#     801     preload_content=preload_content,
#     802     decode_content=decode_content,
#     803     **response_kw,
#     804 )
#     806 # Everything went great!
#     807 clean_exit = True
#
# File /opt/conda/lib/python3.11/site-packages/urllib3/connectionpool.py:537, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535 # Receive the response from the server
#     536 try:
# --> 537     response = conn.getresponse()
#     538 except (BaseSSLError, OSError) as e:
#     539     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File /opt/conda/lib/python3.11/site-packages/urllib3/connection.py:461, in HTTPConnection.getresponse(self)
#     458 from .response import HTTPResponse
#     460 # Get the response from http.client.HTTPConnection
# --> 461 httplib_response = super().getresponse()
#     463 try:
#     464     assert_header_parsing(httplib_response.msg)
#
# File /opt/conda/lib/python3.11/http/client.py:1378, in HTTPConnection.getresponse(self)
#    1376 try:
#    1377     try:
# -> 1378         response.begin()
#    1379     except ConnectionError:
#    1380         self.close()
#
# File /opt/conda/lib/python3.11/http/client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File /opt/conda/lib/python3.11/http/client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File /opt/conda/lib/python3.11/socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# File /opt/conda/lib/python3.11/ssl.py:1311, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1307     if flags != 0:
#    1308         raise ValueError(
#    1309           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1310           self.__class__)
# -> 1311     return self.read(nbytes, buffer)
#    1312 else:
#    1313     return super().recv_into(buffer, nbytes, flags)
#
# File /opt/conda/lib/python3.11/ssl.py:1167, in SSLSocket.read(self, len, buffer)
#    1165 try:
#    1166     if buffer is not None:
# -> 1167         return self._sslobj.read(len, buffer)
#    1168     else:
#    1169         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
df#.to_csv('products.csv')
# Out:
#                                           Description  Old Price  \
# 0                 M  M Natural Preservativos, 3 pzas.        NaN
# 1             M  M Texturizado Preservativos, 3 pzas.        NaN
# 2         M  M Ultra Sensibles Preservativos, 3 pzas.        NaN
# 3       DUREX  Durex Retardante, 3 Condones de Látex.      75.67
# 4   SICO  Sico Sensitive Cartera, 9 Condones de Lá...     238.90
# 5     SICO  Sico Safety Cartera, 9 Condones de Látex.     227.52
# 6   SICO  Sico Clímax Mutuo Cartera, 9 Condones de...     276.43
# 7     SICO  Sico Safety Cartera, 3 Condones de Látex.      83.00
# 8   SICO  Sico Sensitive Cartera, 3 Condones de Lá...      87.17
# 9          DUREX  Durex Clásico, 3 Condones de Látex.      46.06
# 10  SICO  Sico Clímax Mutuo Cartera, 3 Condones de...     105.55
# 11  SICO  Sico Invisible Cartera, 9 Condones de Lá...     275.13
# 12  SICO  Sico Invisible Cartera, 3 Condones de Lá...     105.30
# 13   SICO  Sico Play Cartera, 3 Condones Sabor Fresa.      56.82
# 14        TROJAN  Trojan Condón Piel Desnuda, 9 pzas.     345.05
# 15  TROJAN  Trojan Condón Ecstasy Texturizado, 2 p...     130.77
# 16  DUREX  Durex Ultra Sensitivo Ribbed, 3 Condone...      70.56
# 17             ICE  Trojan Condón Fire & Ice, 3 pzas.     130.77
# 18        TROJAN  Trojan Condón Piel Desnuda, 3 pzas.     130.77
# 19  TROJAN  Trojan Condón Piel Desnuda Puntos de P...     345.05
# 20  PRUDENCE  Cartera Prudence Uniq con 3 Condones...     115.00
# 21  PLAYBOY  Max Sens Condones Party Mix, 12 pzas ...     134.00
# 22  PLAYBOY  Max Sens Condones Tropicana Mix, 3 pz...      42.02
# 23  TRUST  Trust Condones Sabor y Aroma Fresa, 3 p...        NaN
# 24             TRUST  Trust Condones Natural, 3 pzas.        NaN
# 25           TRUST  Trust Condones Sensitivo, 3 pzas.        NaN
# 26          TRUST  Trust Condones Retardante, 3 pzas.        NaN
# 27  TROJAN  Trojan Condón Piel Desnuda Puntos de P...     130.77
# 28   PLAYBOY  Playboy Extra Sensitive Condón, 3 pzas.      56.67
# 29          TROJAN  Trojan Pro-Tech Condones, 3 pzas.     112.79
# 30  PRUDENCE  Prudence Full Sensitive Condón, 3 pzas.        NaN
# 31         PRUDENCE  Prudence Clásico Condón, 3 pzas.        NaN
# 32  PRUDENCE  Prudence Mix Sabor y Aroma Condones,...     125.00
# 33  FULLSEN  FullSen Ultrasensibilidad Condón, 3 p...      49.00
# 34       FULLSEN  Fullsen Texturizado Condón, 3 pzas.      49.00
# 35   SICO  Sico Piel con Piel Cartera Condón, 3 pzas.     116.28
# 36   SICO  Sico Piel con Piel Cartera Condón, 9 pzas.     299.92
# 37  PRUDENCE  Prudence Extra Pleasure Condón, 3 pzas.        NaN
# 38        PLAYBOY  Playboy Texturized Condón, 3 pzas.      56.67
# 39  PLAYBOY  Playboy Lubricants Gel para Masaje Ín...      96.66
# 40  PRUDENCE  Anillo Vibrador Prudence con Condón ...     130.00
# 41        PRUDENCE  Prudence Clásico Condón, 20 pzas.     185.00
# 42       SICO  Sico Play, 3 Condones Sabor Chocolate.      56.82
# 43  PRUDENCE  Preservativos Lubricados Prudence Ex...        NaN
# 44  PRUDENCE  Preservativos Lubricados Prudence Ze...     175.00
# 45  PRUDENCE  Preservativos Lubricados Prudence Ze...      69.00
# 46  SOFTLUBE  SoftLube Pleasure Plus by Sico Lubri...     131.46
# 47  PLAYBOY  Preservativo Playboy Mix & Play, 10 p...     137.65
# 48    PLAYBOY  Preservativo Playboy Paradise, 3 pzas.      56.67
# 49         PLAYBOY  Preservativo Playboy Ink, 3 pzas.      56.67
#
#     Current Price                                               Link
# 0           74.00  http://www.farmaciasguadalajara.com/m-natural-...
# 1           74.00  http://www.farmaciasguadalajara.com/m-texturiz...
# 2           80.50  http://www.farmaciasguadalajara.com/m-ultra-se...
# 3           71.89  http://www.farmaciasguadalajara.com/durex-reta...
# 4          226.95  http://www.farmaciasguadalajara.com/sico-sensi...
# 5          216.14  http://www.farmaciasguadalajara.com/sico-safet...
# 6          262.61  http://www.farmaciasguadalajara.com/sico-clima...
# 7           78.85  http://www.farmaciasguadalajara.com/sico-safet...
# 8           82.81  http://www.farmaciasguadalajara.com/sico-sensi...
# 9           43.76  http://www.farmaciasguadalajara.com/durex-clas...
# 10         100.27  http://www.farmaciasguadalajara.com/sico-clima...
# 11         261.37  http://www.farmaciasguadalajara.com/sico-invis...
# 12         100.03  http://www.farmaciasguadalajara.com/sico-invis...
# 13          53.98  http://www.farmaciasguadalajara.com/sico-play-...
# 14         175.42  http://www.farmaciasguadalajara.com/trojan-con...
# 15          66.33  http://www.farmaciasguadalajara.com/trojan-con...
# 16          67.03  http://www.farmaciasguadalajara.com/durex-ultr...
# 17          66.33  http://www.farmaciasguadalajara.com/trojan-con...
# 18          66.33  http://www.farmaciasguadalajara.com/trojan-con...
# 19         175.42  http://www.farmaciasguadalajara.com/trojan-con...
# 20          79.00  http://www.farmaciasguadalajara.com/cartera-pr...
# 21         127.30  http://www.farmaciasguadalajara.com/ProductDis...
# 22          39.92  http://www.farmaciasguadalajara.com/ProductDis...
# 23          35.00  http://www.farmaciasguadalajara.com/trust-cond...
# 24          35.00  http://www.farmaciasguadalajara.com/trust-cond...
# 25          35.00  http://www.farmaciasguadalajara.com/trust-cond...
# 26          35.00  http://www.farmaciasguadalajara.com/trust-cond...
# 27          66.33  http://www.farmaciasguadalajara.com/trojan-con...
# 28          53.84  http://www.farmaciasguadalajara.com/playboy-ex...
# 29          57.49  http://www.farmaciasguadalajara.com/trojan-pro...
# 30          64.99  http://www.farmaciasguadalajara.com/prudence-f...
# 31          48.00  http://www.farmaciasguadalajara.com/prudence-c...
# 32         110.00  http://www.farmaciasguadalajara.com/prudence-m...
# 33          46.55  http://www.farmaciasguadalajara.com/fullsen-ul...
# 34          46.55  http://www.farmaciasguadalajara.com/fullsen-te...
# 35         110.47  http://www.farmaciasguadalajara.com/sico-piel-...
# 36         284.92  http://www.farmaciasguadalajara.com/sico-piel-...
# 37          64.99  http://www.farmaciasguadalajara.com/prudence-e...
# 38          53.84  http://www.farmaciasguadalajara.com/ProductDis...
# 39          72.49  http://www.farmaciasguadalajara.com/ProductDis...
# 40         110.00  http://www.farmaciasguadalajara.com/anillo-vib...
# 41         170.00  http://www.farmaciasguadalajara.com/prudence-c...
# 42          53.98  http://www.farmaciasguadalajara.com/sico-play-...
# 43          64.99  http://www.farmaciasguadalajara.com/preservati...
# 44         131.25  http://www.farmaciasguadalajara.com/preservati...
# 45          51.75  http://www.farmaciasguadalajara.com/preservati...
# 46         111.74  http://www.farmaciasguadalajara.com/softlube-p...
# 47         130.77  http://www.farmaciasguadalajara.com/preservati...
# 48          53.84  http://www.farmaciasguadalajara.com/preservati...
# 49          53.84  http://www.farmaciasguadalajara.com/preservati...

# %% [markdown]
# ## Farmacias similares

# %%
products = []
total = 1

end = 52;
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/89.0.4389.82 Safari/537.36'
}

# while page<end:
product = "crema"
page = 1

while True:
    URL = f"https://www.farmaciasdesimilares.com/{product}?map=ft&page={page}"
    print(URL)
    response = requests.get(f'{URL}', headers=headers)
    
    if response.status_code != 200:
        print('Error', response.error)
    
    else:
    
        html = BeautifulSoup(response.text, 'html.parser')
        
        items = html.find_all('div', class_="vtex-search-result-3-x-galleryItem vtex-search-result-3-x-galleryItem--normal vtex-search-result-3-x-galleryItem--grid pa4")

        if not items:
            break
        print(len(items))
        for item in items:
        
            description = item.find('span', class_="vtex-product-summary-2-x-productBrand vtex-product-summary-2-x-productBrand--app-name vtex-product-summary-2-x-brandName vtex-product-summary-2-x-brandName--app-name t-body").text
            # link = item.find('a')['href']
            # oldPrice = item.find('span', class_="old_price").text.replace("\n","").replace("\t","").replace("$","") if item.find('span', class_="old_price") else None
            currentPrice = item.find('span', class_="vtex-product-summary-2-x-currencyContainer vtex-product-summary-2-x-currencyContainer--app-price").text.replace("$","")
            
            products.append({
                            "Description" : description,
                            # "Old Price" : float(oldPrice) if oldPrice else None,
                            "Current Price" : float(currentPrice) if currentPrice else None,
                            # "Link" : link
                            })
    page += 1

        
df = pd.DataFrame(products)
# df = df.sort_values("Current Price", ascending=True)
len(df)# df.to_csv('products.csv')
# Out:
# https://www.farmaciasdesimilares.com/crema?map=ft&page=1
# 8
# https://www.farmaciasdesimilares.com/crema?map=ft&page=2
# 8
# https://www.farmaciasdesimilares.com/crema?map=ft&page=3
# 8
# https://www.farmaciasdesimilares.com/crema?map=ft&page=4
# 2
# https://www.farmaciasdesimilares.com/crema?map=ft&page=5
# 26

# %% [markdown]
# ## Farmacias del ahorro

# %%
products = []
total = 1

end = 52;
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/89.0.4389.82 Safari/537.36'
}

# while page<end:
product = "condones"
page = 1

while True:
    URL = f"https://www.fahorro.com/catalogsearch/result/index/?p={page}&q={product}&product_list_limit=24"
    print(URL)
    response = requests.get(f'{URL}', headers=headers)
    html = BeautifulSoup(response.text, 'html.parser')
    items = html.find_all('div', class_="product-item-info")

    if not items:
        break
        
    for item in items:
    
        description = item.find('strong', class_="product name product-item-name").text
        link = item.find('a')['href']
        oldPriceItem = item.find('span', class_="old-price")
        oldPriceValue = oldPriceItem.find('span', class_="price").text.replace("$","").replace(",","") if oldPriceItem else None
        currentPrice = item.find('span', class_="price").text.replace("$","").replace(",","")
        
        products.append({
                        "Description" : description,
                        "Old Price" : float(oldPriceValue) if oldPriceValue else None,
                        "Current Price" : float(currentPrice) if currentPrice else None,
                        "Link" : link
                        })
        
        # time.sleep(2)
    page +=1
    print(len(products))
    
df = pd.DataFrame(products)
df
# Out:
# https://www.fahorro.com/catalogsearch/result/index/?p=1&q=condones&product_list_limit=24
# 24
# https://www.fahorro.com/catalogsearch/result/index/?p=2&q=condones&product_list_limit=24
# 48
# https://www.fahorro.com/catalogsearch/result/index/?p=3&q=condones&product_list_limit=24
# 72
# https://www.fahorro.com/catalogsearch/result/index/?p=4&q=condones&product_list_limit=24
# 75
# https://www.fahorro.com/catalogsearch/result/index/?p=5&q=condones&product_list_limit=24
#                                           Description  Old Price  \
# 0   Prudence Bésame Mucho, 3 funciones, Succionado...        NaN
# 1    Condon M Texturizado Cosquilludo 3 Preservativos        NaN
# 2            Condon M Retard Infinito 3 Preservativos        NaN
# 3   Condon M Bi-Orgasmo M Force & Multi-O 3 Preser...        NaN
# 4   Condon M Ultra Sensible Cuerpo a Cuerpo 3 Pres...        NaN
# ..                                                ...        ...
# 70    Sico Lubricante Íntimo Sensación de Calor 50 ml        NaN
# 71  Sico Softlube Pleasure Plus Lubricante Íntimo ...        NaN
# 72                      Postday 0.75 mg 2 Comprimidos        NaN
# 73                        Postday 1.5 mg 1 Comprimido        NaN
# 74        Sico, Lubricante Íntimo Sabor Cereza, 50 ml        NaN
#
#     Current Price                                               Link
# 0          1059.0  https://www.fahorro.com/prudence-besame-mucho-...
# 1            80.0  https://www.fahorro.com/condon-m-texturizado-c...
# 2            87.0  https://www.fahorro.com/condon-m-retard-infini...
# 3            88.0  https://www.fahorro.com/condon-m-bi-orgasmo-m-...
# 4            87.0  https://www.fahorro.com/condon-m-ultra-sensibl...
# ..            ...                                                ...
# 70          132.0  https://www.fahorro.com/sico-lubricante-intimo...
# 71          122.0  https://www.fahorro.com/sico-softlube-pleasure...
# 72           89.0  https://www.fahorro.com/postday-0-75-mg-2-comp...
# 73          120.0  https://www.fahorro.com/postday-1-5-mg-1-compr...
# 74          131.0  https://www.fahorro.com/sico-lubricante-intimo...
#
# [75 rows x 4 columns]

# %%
# df = df.sort_values("Current Price")
# df.to_csv('products.csv')
df = df[df['Description'].str.startswith("Sico",  na=False)]
df.sort_values("Current Price")
df.to_csv('products.csv')

# %% [markdown]
# ## FARMACIA BENAVIDES

# %%
products = []

headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/89.0.4389.82 Safari/537.36'
}

# while page<end:
product = "condones"
page = 1

while True:
    URL = f"https://www.benavides.com.mx/catalogsearch/result/?p={page}&q={product}&product_list_limit=36"
    print(URL)
    response = requests.get(f'{URL}', headers=headers)
    html = BeautifulSoup(response.text, 'html.parser')
    items = html.find_all('div', class_="product details product-item-details")
    isNextPage = html.find('a', class_ = "action next")
    
    
    for item in items:
    
        description = item.find('strong', class_="product name product-item-name").text.replace("\n\n                                    ","").replace("                               ","").replace("\n","")
        link = item.find('a')['href']
        oldPriceItem = item.find('span', class_="old-price")
        oldPriceValue = oldPriceItem.find('span', class_="price").text.replace("$","").replace(",","") if oldPriceItem else None
        currentPrice = item.find('span', class_="price").text.replace("$","").replace(",","")
        
        products.append({
                        "Description" : description,
                        "Old Price" : float(oldPriceValue) if oldPriceValue else None,
                        "Current Price" : float(currentPrice) if currentPrice else None,
                        "Link" : link
                        })
#     # break
#             # time.sleep(2)

    if not isNextPage:
        break
    page +=1
    
df = pd.DataFrame(products)
df
# Out:
# https://www.benavides.com.mx/catalogsearch/result/?p=1&q=condones&product_list_limit=36
# https://www.benavides.com.mx/catalogsearch/result/?p=2&q=condones&product_list_limit=36
#                                           Description  Old Price  \
# 0                   Prudence Condones Clásicos 20 ud         NaN
# 1                       Prudence Condones Zero 20 ud       275.0
# 2                       Sico Condones Invisible 3 ud         NaN
# 3                        Prudence Condones Zero 3 ud         NaN
# 4           Prudence Condones Efecto Retardante 3 ud         NaN
# 5              Prudence Condones Full Sensitive 3 ud         NaN
# 6                    Sico Condones Clímax Mutuo 3 ud         NaN
# 7               Prudence Condones Caribbean Mix 5 ud         NaN
# 8              Prudence Condones Extra Pleasure 3 ud         NaN
# 9      Trojan Condones Texturizado Piel desnuda 3 ud         NaN
# 10          Prudence Condones Sabor y Aroma Mix 5 ud         NaN
# 11         Prudence Condones Mix Sabor y Aroma 20 ud       219.0
# 12                  Sico Condones Piel con Piel 3 ud         NaN
# 13    Trojan Condones Piel Desnuda Sensibilidad 3 ud         NaN
# 14             Prudence Uniq Condones Sin Látex 3 ud         NaN
# 15         Prudence Condones Sabor y Aroma Mix 10 ud         NaN
# 16  Prudence Condones Make Love Vete a la Versh 5 ud         NaN
# 17  Prudence BESAME MUCHO 3 EN 1 SUCCIONADOR + LUB...     1049.9
# 18                      Sico Condones Invisible 9 ud         NaN
# 19                   Durex Condones Retardante 18 ud         NaN
# 20              Sico Condones Sensitive Delgado 3 ud         NaN
# 21               Sico Condones Safety Seguridad 9 ud         NaN
# 22                        M Condones Bi-Orgasmo 3 ud         NaN
# 23               Sico Condones Safety Seguridad 3 ud         NaN
# 24              Sico Condones Sensitive Delgado 9 ud         NaN
# 25                 Trojan Piel Desnuda Condones 9 ud         NaN
# 26           M Condones Cosquillido Texturizado 3 ud         NaN
# 27                    M Condones Placer Natural 3 ud         NaN
# 28          Trojan Condones Ecstasy Texturizado 2 ud         NaN
# 29                   Sico Condones Clímax Mutuo 9 ud         NaN
# 30           Trojan Condones Pro-Tech Seguridad 3 ud         NaN
# 31                  Sico Condones Piel con Piel 9 ud         NaN
# 32        Prudence Condones Sabor y Aroma Fresa 3 ud         NaN
# 33   Trojan Condones Piel Desnuda Sensibilidad 15 ud         NaN
# 34           Sico Play Condones Fresa Saboreame 3 ud         NaN
# 35      Sico Condones Play Mix Mayor Diversión 20 ud         NaN
# 36   Sico Play Condones Texturizado Dame Placer 3 ud         NaN
# 37        Max Sens Condones Party Mix Max Sens 12 ud         NaN
# 38      Sico Condones Play Mix Mayor Diversión 20 ud         NaN
# 39  M Condones Infinito Retarda el Climax Masculin...        NaN
# 40  Trojan Condones Piel Desnuda Puntos de Placer ...        NaN
# 41    M Condones Ultra Sensible Cuerpo a Cuerpo 3 ud         NaN
# 42  Trojan Condones Fire y Ice Lubricante de Doble...        NaN
# 43                      Prudence Condón Clásico 1 ud         NaN
# 44       Sico Play Chocolate Derríteme 3 ud Condones         NaN
#
#     Current Price                                               Link
# 0          190.00  https://www.benavides.com.mx/condones-prudence...
# 1          220.00  https://www.benavides.com.mx/prudence-zero-20-...
# 2          103.00  https://www.benavides.com.mx/sico-condones-inv...
# 3           69.00  https://www.benavides.com.mx/prudence-zero-3-u...
# 4           65.00  https://www.benavides.com.mx/prudence-retardan...
# 5           75.00  https://www.benavides.com.mx/prudence-full-sen...
# 6          115.00  https://www.benavides.com.mx/sico-condones-cli...
# 7           77.00  https://www.benavides.com.mx/condones-prudence...
# 8           75.00  https://www.benavides.com.mx/prudence-extra-pl...
# 9           93.00  https://www.benavides.com.mx/trojan-piel-desnu...
# 10          90.00  https://www.benavides.com.mx/condones-prudence...
# 11         175.20  https://www.benavides.com.mx/condones-prudence...
# 12         114.00  https://www.benavides.com.mx/sico-piel-con-pie...
# 13          93.00  https://www.benavides.com.mx/trojan-preserv-pi...
# 14         135.00  https://www.benavides.com.mx/prudence-uniq-sin...
# 15         121.00  https://www.benavides.com.mx/condones-prudence...
# 16          75.00  https://www.benavides.com.mx/prudence-sabor-ch...
# 17         839.92  https://www.benavides.com.mx/1049552-besame-mu...
# 18         271.00  https://www.benavides.com.mx/sico-condones-inv...
# 19         265.00  https://www.benavides.com.mx/durex-condones-re...
# 20          90.00  https://www.benavides.com.mx/sico-condones-sen...
# 21         209.00  https://www.benavides.com.mx/sico-condones-saf...
# 22          90.00  https://www.benavides.com.mx/m-force-multi-o-c...
# 23          84.00  https://www.benavides.com.mx/sico-condones-saf...
# 24         230.00  https://www.benavides.com.mx/sico-condones-sen...
# 25         219.00  https://www.benavides.com.mx/condones-trojan-p...
# 26          79.00  https://www.benavides.com.mx/condon-m-texturiz...
# 27          84.00  https://www.benavides.com.mx/condon-m-natural-...
# 28          93.00  https://www.benavides.com.mx/trojan-ecstasy-pr...
# 29         260.00  https://www.benavides.com.mx/sico-climax-mutuo...
# 30          86.00  https://www.benavides.com.mx/condones-trojan-p...
# 31         295.00  https://www.benavides.com.mx/sico-piel-con-pie...
# 32          60.00  https://www.benavides.com.mx/condones-prudence...
# 33         233.00  https://www.benavides.com.mx/1048189-condones-...
# 34          57.00  https://www.benavides.com.mx/sico-play-fresa-3...
# 35         261.00  https://www.benavides.com.mx/sico-play-mix-20-...
# 36          64.00  https://www.benavides.com.mx/sico-play-texturi...
# 37         140.00  https://www.benavides.com.mx/max-sens-party-mi...
# 38         261.00  https://www.benavides.com.mx/sico-play-mix-20-...
# 39          90.00  https://www.benavides.com.mx/condon-m-retard-3...
# 40         219.00  https://www.benavides.com.mx/condones-trojan-p...
# 41          90.00  https://www.benavides.com.mx/condon-m-ultra-se...
# 42          99.00  https://www.benavides.com.mx/trojan-fire-y-ice...
# 43          55.00  https://www.benavides.com.mx/condones-prudence...
# 44          57.00  https://www.benavides.com.mx/1048276-play-choc...

# %%
df.to_csv("productos.csv")

# %% [markdown]
# ## FARMACIA YZA

# %%
products = []
start = 0
product = "cerave"
szPerPage = 54
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/89.0.4389.82 Safari/537.36'
}

# while page<end:
# product = "crema"
page = 1

while True:
    # URL = f"https://www.yza.mx/on/demandware.store/Sites-YzaMexico-Site/es_MX/Search-UpdateGrid?&start={(start*szPerPage)}&sz={szPerPage}"
    URL = f"https://www.yza.mx/busqueda?q={product}&search-button=&lang=es_M&start={((start*szPerPage))}&sz=54&maxsize=54"
    print(URL)
    response = requests.get(f'{URL}', headers=headers)
    html = BeautifulSoup(response.text, 'html.parser')
    items = html.find_all('div', class_="product product-wrapper")
    if not items:
        break
    
    for item in items:
    
        description = item.find('div', class_="pdp-link").text.replace("\n\n            \n                ","").replace("\n            \n        \n","").replace(" ","", 1)
        link = item.find('a')['href']
        # oldPriceItem = item.find('span', class_="old-price")
        oldPriceValue = item.find('span', class_="price-original").text.replace("$","").replace(",","").replace("\n","").replace(" ","").replace("(Antes)", "") if item.find('span', class_="price-original") else None
        currentPrice = item.find('span', class_="value").text.replace("$","").replace(",","").replace("\n","").replace(" ","").replace("(Oferta)", "")
        
        products.append({
                        "Description" : description,
                        "Old Price" : oldPriceValue,#) if oldPriceValue else None,
                        "Current Price" : currentPrice if currentPrice else None,
                        "Link" : f"https://www.yza.mx{link}"
                        })
#     # break
#             # time.sleep(2)
    # break
  
    start +=1
    
df = pd.DataFrame(products)
df
# Out:
# https://www.yza.mx/busqueda?q=cerave&search-button=&lang=es_M&start=0&sz=54&maxsize=54
# https://www.yza.mx/busqueda?q=cerave&search-button=&lang=es_M&start=54&sz=54&maxsize=54
# https://www.yza.mx/busqueda?q=cerave&search-button=&lang=es_M&start=108&sz=54&maxsize=54
#                                  Description Old Price Current Price  \
# 0         CERAVEGEL LIMPIADOR ESPUMOSO 236ML    387.00        318.00
# 1                CERAVECREMA HIDRATANTE 170G    260.00        200.00
# 2     BiodermaAtoderm Intensive Balsam 500Ml    728.00        582.40
# 3     BiodermaPigmentbio Sensitive Area 75Ml    745.00        596.00
# 4                CERAVECREMA HIDRATANTE 454G    418.50        374.00
# ..                                       ...       ...           ...
# 85  VichyCapital Soleil Family Fps 50 300 Ml    916.00          None
# 86       BiodermaPhotoderm Spray Spf50+ 30Ml    734.00          None
# 87        BiodermaPhotoderm Nude Dorado 40Ml    611.50          None
# 88    BiodermaPhotoderm Cover Muy Claro 40Ml    634.50          None
# 89       BiodermaPhotoderm Cover Bronce 40Ml    634.50          None
#
#                                                  Link
# 0   https://www.yza.mx/cerave-gel-limpiador-espumo...
# 1   https://www.yza.mx/cerave-crema-hidratante-170...
# 2   https://www.yza.mx/bioderma-atoderm-intensive-...
# 3   https://www.yza.mx/bioderma-pigmentbio-sensiti...
# 4   https://www.yza.mx/cerave-crema-hidratante-454...
# ..                                                ...
# 85  https://www.yza.mx/vichy-capital-soleil-family...
# 86  https://www.yza.mx/bioderma-photoderm-spray-sp...
# 87  https://www.yza.mx/bioderma-photoderm-nude-dor...
# 88  https://www.yza.mx/bioderma-photoderm-cover-mu...
# 89  https://www.yza.mx/bioderma-photoderm-cover-br...
#
# [90 rows x 4 columns]

# %%
df.to_csv('productos.csv')

# %%
products
# Out:
# [{'Description': 'CERAVEGEL LIMPIADOR ESPUMOSO 236ML',
#   'Old Price': '387.00',
#   'Current Price': '318.00',
#   'Link': 'https://www.yza.mx/cerave-gel-limpiador-espumoso-236ml/MXYZ_3337875597197.html'},
#  {'Description': 'CERAVECREMA HIDRATANTE 454G',
#   'Old Price': '418.50',
#   'Current Price': '372.00',
#   'Link': 'https://www.yza.mx/cerave-crema-hidratante-454g/MXYZ_3337875597388.html'},
#  {'Description': 'CERAVECREMA HIDRATANTE 170G',
#   'Old Price': '260.00',
#   'Current Price': '200.00',
#   'Link': 'https://www.yza.mx/cerave-crema-hidratante-170g/MXYZ_3337875598996.html'},
#  {'Description': 'BiodermaPhotoderm Aquafluide Clar 40Ml',
#   'Old Price': '554.50',
#   'Current Price': '443.60',
#   'Link': 'https://www.yza.mx/bioderma-photoderm-aquafluide-clar-40ml/MXYZ_3701129804384.html'},
#  {'Description': 'BiodermaAtoderm Intensive Balsam 500Ml',
#   'Old Price': '728.00',
#   'Current Price': '582.40',
#   'Link': 'https://www.yza.mx/bioderma-atoderm-intensive-balsam-500ml/MXYZ_3701129802076.html'},
#  {'Description': 'CERAVEHIDRATANTE LIMPIADORA FACIAL 237ML',
#   'Old Price': '382.00',
#   'Current Price': None,
#   'Link': 'https://www.yza.mx/cerave-hidratante-limpiadora-facial-237ml/MXYZ_3337875597180.html'},
#  {'Description': 'VichyMineral 89 50ml ',
#   'Old Price': '839.00',
#   'Current Price': '671.20',
#   'Link': 'https://www.yza.mx/vichy-mineral-89-50ml-/MXYZ_3337875543248.html'},
#  {'Description': 'VichyIdeal Soleil Fps 50 200 Ml',
#   'Old Price': '559.00',
#   'Current Price': None,
#   'Link': 'https://www.yza.mx/vichy-ideal-soleil-fps-50-200-ml/MXYZ_3337875558037.html'},
#  {'Description': 'CremaCorporal CeraVe Antirrugosidades 170g ',
#   'Old Price': '377.00',
#   'Current Price': '335.00',
#   'Link': 'https://www.yza.mx/crema-corporal-cerave-antirrugosidades-170g-/MXYZ_3337875684095.html'},
#  {'Description': 'VichiIdeal Soleil Toque Seco Fps 50 50 Ml',
#   'Old Price': '776.00',
#   'Current Price': None,
#   'Link': 'https://www.yza.mx/vichi-ideal-soleil-toque-seco-fps-50-50-ml/MXYZ_3337871323622.html'},
#  {'Description': 'BiodermaPigmentbio Diario Spf 50+ 40Ml',
#   'Old Price': '936.90',
#   'Current Price': None,
#   'Link': 'https://www.yza.mx/bioderma-pigmentbio-diario-spf-50-40ml/MXYZ_3701129800072.html'},
#  {'Description': 'VichyNeovadio Bi-Serum Rfrmnt Nut 30Ml',
#   'Old Price': '1449.90',
#   'Current Price': '1232.41',
#   'Link': 'https://www.yza.mx/vichy-neovadio-bi-serum-rfrmnt-nut-30ml/MXYZ_3337875773980.html'},
#  {'Description': 'BiodermaSensibio Gel Moussant 500Ml',
#   'Old Price': '743.00',
#   'Current Price': None,
#   'Link': 'https://www.yza.mx/bioderma-sensibio-gel-moussant-500ml/MXYZ_3701129800843.html'},
#  {'Description': 'CeraveLocion Hidratante Rostro Pm 52Ml',
#   'Old Price': '483.00',
#   'Current Price': '386.40',
#   'Link': 'https://www.yza.mx/cerave-locion-hidratante-rostro-pm-52ml/MXYZ_3337875597449.html'},
#  {'Description': 'CeraveCrema Hidratante Piel Seca 50Ml',
#   'Old Price': '147.00',
#   'Current Price': None,
#   'Link': 'https://www.yza.mx/cerave-crema-hidratante-piel-seca-50ml/MXYZ_3337875597371.html'},
#  {'Description': 'CeraveLimpiador En Aceite Ducha 236Ml',
#   'Old Price': '376.00',
#   'Current Price': None,
#   'Link': 'https://www.yza.mx/cerave-limpiador-en-aceite-ducha-236ml/MXYZ_3337875773430.html'},
#  {'Description': 'BiodermaSébium Gel Moussant Acti 200Ml',
#   'Old Price': '546.00',
#   'Current Price': '436.80',
#   'Link': 'https://www.yza.mx/bioderma-sebium-gel-moussant-acti-200ml/MXYZ_3701129803400.html'},
#  {'Description': 'VichyNeo Postmeno Antisggnss Day 50Ml',
#   'Old Price': '1063.90',
#   'Current Price': '904.31',
#   'Link': 'https://www.yza.mx/vichy-neo-postmeno-antisggnss-day-50ml/MXYZ_3337875774031.html'},
#  {'Description': 'BiodermaPhotoderm Aquafluide Neut 40Ml',
#   'Old Price': '554.50',
#   'Current Price': '443.60',
#   'Link': 'https://www.yza.mx/bioderma-photoderm-aquafluide-neut-40ml/MXYZ_3701129804377.html'},
#  {'Description': 'CeraveLimpiador Espumoso Hidrata 473Ml',
#   'Old Price': '514.00',
#   'Current Price': None,
#   'Link': 'https://www.yza.mx/cerave-limpiador-espumoso-hidrata-473ml/MXYZ_3337875773447.html'},
#  {'Description': 'CeraveCrema Anti-Rugosidades 340G',
#   'Old Price': '597.50',
#   'Current Price': '448.12',
#   'Link': 'https://www.yza.mx/cerave-crema-anti-rugosidades-340g/MXYZ_3337875684101.html'},
#  {'Description': 'VichyDermablend Covermatte 9.5G',
#   'Old Price': '767.90',
#   'Current Price': None,
#   'Link': 'https://www.yza.mx/vichy-dermablend-covermatte-9.5g/MXYZ_3337875561761.html'},
#  {'Description': 'VichyDercos Densi Solutions 100Ml',
#   'Old Price': '1302.90',
#   'Current Price': None,
#   'Link': 'https://www.yza.mx/vichy-dercos-densi-solutions-100ml/MXYZ_3337875574372.html'},
#  {'Description': 'VichyMineral 89 50Ml',
#   'Old Price': '599.90',
#   'Current Price': None,
#   'Link': 'https://www.yza.mx/vichy-mineral-89-50ml/MXYZ_3337875831888.html'},
#  {'Description': 'VichyLiftactiv Ojos 15Ml',
#   'Old Price': '988.00',
#   'Current Price': '839.80',
#   'Link': 'https://www.yza.mx/vichy-liftactiv-ojos-15ml/MXYZ_3337871323332.html'},
#  {'Description': 'VichyLiftactiv B3 Antimanc Oscura 50Ml',
#   'Old Price': '1344.90',
#   'Current Price': '1143.16',
#   'Link': 'https://www.yza.mx/vichy-liftactiv-b3-antimanc-oscura-50ml/MXYZ_3337875832724.html'},
#  {'Description': 'VichyProtector Solar Color 40Ml',
#   'Old Price': '691.00',
#   'Current Price': None,
#   'Link': 'https://www.yza.mx/vichy-protector-solar-color-40ml/MXYZ_3337875795265.html'},
#  {'Description': 'VichyNormaderm Anti-Imperfeccione 30Ml',
#   'Old Price': '822.90',
#   'Current Price': None,
#   'Link': 'https://www.yza.mx/vichy-normaderm-anti-imperfeccione-30ml/MXYZ_3337875791984.html'},
#  {'Description': 'VichyNormaderm Anti Manchas 50Ml',
#   'Old Price': '860.50',
#   'Current Price': None,
#   'Link': 'https://www.yza.mx/vichy-normaderm-anti-manchas-50ml/MXYZ_3337875660617.html'},
#  {'Description': 'VichyDercos Caspa Seca 200Ml',
#   'Old Price': '597.00',
#   'Current Price': '507.45',
#   'Link': 'https://www.yza.mx/vichy-dercos-caspa-seca-200ml/MXYZ_3337871330262.html'},
#  {'Description': 'BiodermaSensibio Ds+ Crema 40Ml',
#   'Old Price': '613.00',
#   'Current Price': None,
#   'Link': 'https://www.yza.mx/bioderma-sensibio-ds-crema-40ml/MXYZ_3401397240470.html'},
#  {'Description': 'VichyLifactiv Ha Epidermic Filler 30Ml',
#   'Old Price': '803.90',
#   'Current Price': '683.31',
#   'Link': 'https://www.yza.mx/vichy-lifactiv-ha-epidermic-filler-30ml/MXYZ_3337875719209.html'},
#  {'Description': 'BiodermaSébium Gel 200Ml',
#   'Old Price': '462.00',
#   'Current Price': None,
#   'Link': 'https://www.yza.mx/bioderma-sebium-gel-200ml/MXYZ_3401353806399.html'},
#  {'Description': 'BiodermaSensibio H2O 500Ml',
#   'Old Price': '740.00',
#   'Current Price': '592.00',
#   'Link': 'https://www.yza.mx/bioderma-sensibio-h2o-500ml/MXYZ_3401345935571.html'},
#  {'Description': 'IdealSoleil Antiedad Fps 50 Vichy 50 Ml',
#   'Old Price': '724.00',
#   'Current Price': '615.40',
#   'Link': 'https://www.yza.mx/ideal-soleil-antiedad-fps-50-vichy-50-ml/MXYZ_3337875585231.html'},
#  {'Description': 'CeraveAnti-Imperfecciones Gel 40Ml',
#   'Old Price': '459.00',
#   'Current Price': None,
#   'Link': 'https://www.yza.mx/cerave-anti-imperfecciones-gel-40ml/MXYZ_3337875782357.html'},
#  {'Description': 'BiodermaSensibio Gel Moussant 100Ml',
#   'Old Price': '281.00',
#   'Current Price': None,
#   'Link': 'https://www.yza.mx/bioderma-sensibio-gel-moussant-100ml/MXYZ_3701129800850.html'},
#  {'Description': 'VichyDes Stress-R 50Ml',
#   'Old Price': '511.90',
#   'Current Price': None,
#   'Link': 'https://www.yza.mx/vichy-des-stress-r-50ml/MXYZ_3337871324001.html'},
#  {'Description': 'VichyLftactiv Specialist 30Ml',
#   'Old Price': '1049.50',
#   'Current Price': '734.65',
#   'Link': 'https://www.yza.mx/vichy-lftactiv-specialist-30ml/MXYZ_3337875734905.html'},
#  {'Description': 'VichyGel Limpiador Phytosolution 400Ml',
#   'Old Price': '788.00',
#   'Current Price': None,
#   'Link': 'https://www.yza.mx/vichy-gel-limpiador-phytosolution-400ml/MXYZ_3337875663083.html'},
#  {'Description': 'VichyLiftactiv Crema Retinol 50Ml',
#   'Old Price': '1173.90',
#   'Current Price': None,
#   'Link': 'https://www.yza.mx/vichy-liftactiv-crema-retinol-50ml/MXYZ_3337875873086.html'},
#  {'Description': 'BiodermaSébium H2O 100Ml',
#   'Old Price': '222.90',
#   'Current Price': '200.00',
#   'Link': 'https://www.yza.mx/bioderma-sebium-h2o-100ml/MXYZ_3401395376935.html'},
#  {'Description': 'AguaTermal Vichy 300 Ml',
#   'Old Price': '533.00',
#   'Current Price': None,
#   'Link': 'https://www.yza.mx/agua-termal-vichy-300-ml/MXYZ_3337871321963.html'},
#  {'Description': 'BiodermaSensibio H2O 100Ml',
#   'Old Price': '238.00',
#   'Current Price': None,
#   'Link': 'https://www.yza.mx/bioderma-sensibio-h2o-100ml/MXYZ_3401395376706.html'},
#  {'Description': 'BiodermaHydrabio Sérum 40Ml',
#   'Old Price': '750.00',
#   'Current Price': '600.00',
#   'Link': 'https://www.yza.mx/bioderma-hydrabio-serum-40ml/MXYZ_3401347869775.html'},
#  {'Description': 'VichyIdeal Soleil Anti Dark Spots 50Ml',
#   'Old Price': '724.90',
#   'Current Price': '616.16',
#   'Link': 'https://www.yza.mx/vichy-ideal-soleil-anti-dark-spots-50ml/MXYZ_3337875419802.html'},
#  {'Description': 'CeraveLimpiadora Crema Espumosa 100Ml',
#   'Old Price': '282.90',
#   'Current Price': None,
#   'Link': 'https://www.yza.mx/cerave-limpiadora-crema-espumosa-100ml/MXYZ_3337875743556.html'},
#  {'Description': 'VichyCapital Soleil Spf50 50Ml',
#   'Old Price': '723.90',
#   'Current Price': '615.31',
#   'Link': 'https://www.yza.mx/vichy-capital-soleil-spf50-50ml/MXYZ_3337875695176.html'},
#  {'Description': 'VichyNeo Peri Meno Night Cream 50Ml',
#   'Old Price': '1339.00',
#   'Current Price': '1138.15',
#   'Link': 'https://www.yza.mx/vichy-neo-peri-meno-night-cream-50ml/MXYZ_3337875774123.html'},
#  {'Description': 'VichyDercos Densi Solutions 250Ml',
#   'Old Price': '702.90',
#   'Current Price': None,
#   'Link': 'https://www.yza.mx/vichy-dercos-densi-solutions-250ml/MXYZ_3337875574358.html'},
#  {'Description': 'CeraveLimpiadora Hidratante 473Ml',
#   'Old Price': '535.00',
#   'Current Price': '428.00',
#   'Link': 'https://www.yza.mx/cerave-limpiadora-hidratante-473ml/MXYZ_3337875597333.html'},
#  {'Description': 'VichyHom Structure Force 50Ml',
#   'Old Price': '853.90',
#   'Current Price': None,
#   'Link': 'https://www.yza.mx/vichy-hom-structure-force-50ml/MXYZ_3337875647212.html'},
#  {'Description': 'CeraveAgua Micelar Limpiadora 295Ml',
#   'Old Price': '399.90',
#   'Current Price': None,
#   'Link': 'https://www.yza.mx/cerave-agua-micelar-limpiadora-295ml/MXYZ_3337875597203.html'},
#  {'Description': 'BiodermaSensibio Defensive Serum 30Ml',
#   'Old Price': '700.00',
#   'Current Price': None,
#   'Link': 'https://www.yza.mx/bioderma-sensibio-defensive-serum-30ml/MXYZ_3701129804995.html'},
#  {'Description': 'VichyCra Liftactiv Collagen Spec 50Ml',
#   'Old Price': '1030.90',
#   'Current Price': '876.26',
#   'Link': 'https://www.yza.mx/vichy-cra-liftactiv-collagen-spec-50ml/MXYZ_3337875607254.html'},
#  {'Description': 'BiodermaPhotoderm Nude Muy Claro 40Ml',
#   'Old Price': '611.50',
#   'Current Price': None,
#   'Link': 'https://www.yza.mx/bioderma-photoderm-nude-muy-claro-40ml/MXYZ_3701129803455.html'},
#  {'Description': 'BiodermaPhotoderm Cover Claro 40Ml',
#   'Old Price': '634.50',
#   'Current Price': None,
#   'Link': 'https://www.yza.mx/bioderma-photoderm-cover-claro-40ml/MXYZ_3701129803424.html'},
#  {'Description': 'BiodermaPhotoderm Aquafluide Dora 40Ml',
#   'Old Price': '554.50',
#   'Current Price': '443.60',
#   'Link': 'https://www.yza.mx/bioderma-photoderm-aquafluide-dora-40ml/MXYZ_3701129804391.html'},
#  {'Description': 'BiodermaHydrabio Gel Crema 40Ml',
#   'Old Price': '554.00',
#   'Current Price': '443.20',
#   'Link': 'https://www.yza.mx/bioderma-hydrabio-gel-crema-40ml/MXYZ_3401329447809.html'},
#  {'Description': 'BiodermaSensibio Gel Moussant 200Ml',
#   'Old Price': '537.50',
#   'Current Price': None,
#   'Link': 'https://www.yza.mx/bioderma-sensibio-gel-moussant-200ml/MXYZ_3401381507565.html'},
#  {'Description': 'VichyDercos Caspa Grasa 200Ml',
#   'Old Price': '597.00',
#   'Current Price': '507.45',
#   'Link': 'https://www.yza.mx/vichy-dercos-caspa-grasa-200ml/MXYZ_3337871330286.html'},
#  {'Description': 'BiodermaSensibio Ar Crema 40Ml',
#   'Old Price': '726.00',
#   'Current Price': None,
#   'Link': 'https://www.yza.mx/bioderma-sensibio-ar-crema-40ml/MXYZ_3401343696245.html'},
#  {'Description': 'CeraveLimpiadora Crema Hidratant 236Ml',
#   'Old Price': '472.90',
#   'Current Price': None,
#   'Link': 'https://www.yza.mx/cerave-limpiadora-crema-hidratant-236ml/MXYZ_3337875743563.html'},
#  {'Description': 'VichyLiftactiv Retinol Serum 30Ml',
#   'Old Price': '1009.00',
#   'Current Price': '857.65',
#   'Link': 'https://www.yza.mx/vichy-liftactiv-retinol-serum-30ml/MXYZ_3337875821636.html'},
#  {'Description': 'VichyLiftactiv Supreme Anti-Arrug 50Ml',
#   'Old Price': '1173.90',
#   'Current Price': None,
#   'Link': 'https://www.yza.mx/vichy-liftactiv-supreme-anti-arrug-50ml/MXYZ_3337871322502.html'},
#  {'Description': 'CERAVELIMPIADOR CONTROL IMPERFECCIONES 8OZ',
#   'Old Price': '408.00',
#   'Current Price': None,
#   'Link': 'https://www.yza.mx/cerave-limpiador-control-imperfecciones-8oz/MXYZ_3337875784054.html'},
#  {'Description': 'BiodermaSébium Gel 500Ml',
#   'Old Price': '743.00',
#   'Current Price': '594.40',
#   'Link': 'https://www.yza.mx/bioderma-sebium-gel-500ml/MXYZ_3401399277092.html'},
#  {'Description': 'BiodermaSébium Gel 100Ml',
#   'Old Price': '325.00',
#   'Current Price': '246.00',
#   'Link': 'https://www.yza.mx/bioderma-sebium-gel-100ml/MXYZ_3401353791220.html'},
#  {'Description': 'BiodermaPigmentbio Night Renewer 50Ml',
#   'Old Price': '936.90',
#   'Current Price': None,
#   'Link': 'https://www.yza.mx/bioderma-pigmentbio-night-renewer-50ml/MXYZ_3701129800089.html'},
#  {'Description': 'VICHYMINERAL 89 30ML',
#   'Old Price': '499.00',
#   'Current Price': None,
#   'Link': 'https://www.yza.mx/vichy-mineral-89-30ml/MXYZ_3337875594516.html'},
#  {'Description': 'VichiIdeal Soleil Toque Seco Fps 50',
#   'Old Price': '743.00',
#   'Current Price': None,
#   'Link': 'https://www.yza.mx/vichi-ideal-soleil-toque-seco-fps-50/MXYZ_3337871325787.html'},
#  {'Description': 'BiodermaAtoderm Aceite De Ducha 200Ml',
#   'Old Price': '310.00',
#   'Current Price': '248.00',
#   'Link': 'https://www.yza.mx/bioderma-atoderm-aceite-de-ducha-200ml/MXYZ_3401528519895.html'},
#  {'Description': 'VichyMinéral 89 Ojos Sérum Hidra 15Ml',
#   'Old Price': '691.00',
#   'Current Price': '552.80',
#   'Link': 'https://www.yza.mx/vichy-mineral-89-ojos-serum-hidra-15ml/MXYZ_3337875596763.html'},
#  {'Description': 'CeraveSa Crema Renovadora De Pies 88Ml',
#   'Old Price': '400.00',
#   'Current Price': None,
#   'Link': 'https://www.yza.mx/cerave-sa-crema-renovadora-de-pies-88ml/MXYZ_3337875597296.html'},
#  {'Description': 'BiodermaSensibio Defensive 40Ml',
#   'Old Price': '446.90',
#   'Current Price': None,
#   'Link': 'https://www.yza.mx/bioderma-sensibio-defensive-40ml/MXYZ_3701129804452.html'},
#  {'Description': 'VichyNeo Peri Meno Day Cream 50Ml',
#   'Old Price': '1329.90',
#   'Current Price': '1130.41',
#   'Link': 'https://www.yza.mx/vichy-neo-peri-meno-day-cream-50ml/MXYZ_3337875774086.html'},
#  {'Description': 'BiodermaAtoderm Manos Y Uñas 50Ml',
#   'Old Price': '132.50',
#   'Current Price': '106.00',
#   'Link': 'https://www.yza.mx/bioderma-atoderm-manos-y-unas-50ml/MXYZ_3701129804193.html'},
#  {'Description': 'BiodermaSensibio H2O Eye 125Ml',
#   'Old Price': '423.50',
#   'Current Price': None,
#   'Link': 'https://www.yza.mx/bioderma-sensibio-h2o-eye-125ml/MXYZ_3401360212237.html'},
#  {'Description': 'BiodermaSébium H2O 500Ml',
#   'Old Price': '708.00',
#   'Current Price': '566.40',
#   'Link': 'https://www.yza.mx/bioderma-sebium-h2o-500ml/MXYZ_3401575645851.html'},
#  {'Description': 'VichyLift Activ Vit C Skin 20Ml',
#   'Old Price': '1018.00',
#   'Current Price': '865.30',
#   'Link': 'https://www.yza.mx/vichy-lift-activ-vit-c-skin-20ml/MXYZ_3337875796583.html'},
#  {'Description': 'VichyCapital Soleil Family Fps 50 300 Ml',
#   'Old Price': '998.50',
#   'Current Price': None,
#   'Link': 'https://www.yza.mx/vichy-capital-soleil-family-fps-50-300-ml/MXYZ_3337871322694.html'},
#  {'Description': 'BiodermaPigmentbio C-Concentrate 15Ml',
#   'Old Price': '804.00',
#   'Current Price': '643.20',
#   'Link': 'https://www.yza.mx/bioderma-pigmentbio-c-concentrate-15ml/MXYZ_3701129800119.html'},
#  {'Description': 'BiodermaPhotoderm Spray Spf50+ 30Ml',
#   'Old Price': '734.00',
#   'Current Price': None,
#   'Link': 'https://www.yza.mx/bioderma-photoderm-spray-spf50-30ml/MXYZ_3701129809921.html'},
#  {'Description': 'BiodermaPhotoderm Nude Dorado 40Ml',
#   'Old Price': '611.50',
#   'Current Price': None,
#   'Link': 'https://www.yza.mx/bioderma-photoderm-nude-dorado-40ml/MXYZ_3701129803462.html'},
#  {'Description': 'BiodermaPhotoderm Cover Muy Claro 40Ml',
#   'Old Price': '634.50',
#   'Current Price': None,
#   'Link': 'https://www.yza.mx/bioderma-photoderm-cover-muy-claro-40ml/MXYZ_3701129807415.html'},
#  {'Description': 'BiodermaPhotoderm Cover Bronce 40Ml',
#   'Old Price': '562.90',
#   'Current Price': None,
#   'Link': 'https://www.yza.mx/bioderma-photoderm-cover-bronce-40ml/MXYZ_3701129807422.html'},
#  {'Description': 'BiodermaHydrabio Bruma 300Ml',
#   'Old Price': '309.50',
#   'Current Price': '247.60',
#   'Link': 'https://www.yza.mx/bioderma-hydrabio-bruma-300ml/MXYZ_3401399848254.html'},
#  {'Description': 'VichyMineral 89 Probiotic Fract 30Ml',
#   'Old Price': '1018.00',
#   'Current Price': None,
#   'Link': 'https://www.yza.mx/vichy-mineral-89-probiotic-fract-30ml/MXYZ_3337875762908.html'},
#  {'Description': 'BiodermaPigmentbio Sensitive Area 75Ml',
#   'Old Price': '745.00',
#   'Current Price': '596.00',
#   'Link': 'https://www.yza.mx/bioderma-pigmentbio-sensitive-area-75ml/MXYZ_3701129800096.html'},
#  {'Description': 'BiodermaPigmentbio Foaming Cream 200Ml',
#   'Old Price': '713.00',
#   'Current Price': '570.40',
#   'Link': 'https://www.yza.mx/bioderma-pigmentbio-foaming-cream-200ml/MXYZ_3701129800546.html'}]
